# %%
import numpy as np
import pandas as pd

# %%
fn=pd.read_csv("SalaryData_Train.csv")
fn
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %%
fn.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
from sklearn import preprocessing
le=preprocessing.LabelEncoder()
for column_name in fn.columns:
    if fn[column_name].dtype == object:
        fn[column_name] = le.fit_transform(fn[column_name])
    else:
        pass
fn
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30156   27          2          7           12              2          12
# 30157   40          2         11            9              2           6
# 30158   58          2         11            9              6           0
# 30159   22          2         11            9              4           0
# 30160   52          3         11            9              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
def norm_func(i):
    x = (i-i.min()) / (i.max() - i.min())
    return (x)

# %%
fn = norm_func(fn.iloc[:,1:])
fn
# Out:
#        workclass  education  educationno  maritalstatus  occupation  \
# 0       0.833333   0.600000     0.800000       0.666667    0.000000
# 1       0.666667   0.600000     0.800000       0.333333    0.230769
# 2       0.333333   0.733333     0.533333       0.000000    0.384615
# 3       0.333333   0.066667     0.400000       0.333333    0.384615
# 4       0.333333   0.600000     0.800000       0.333333    0.692308
# ...          ...        ...          ...            ...         ...
# 30156   0.333333   0.466667     0.733333       0.333333    0.923077
# 30157   0.333333   0.733333     0.533333       0.333333    0.461538
# 30158   0.333333   0.733333     0.533333       1.000000    0.000000
# 30159   0.333333   0.733333     0.533333       0.666667    0.000000
# 30160   0.500000   0.733333     0.533333       0.333333    0.230769
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# 0               0.2   1.0  1.0     0.021740          0.0      0.397959
# ...

# %%
from sklearn.naive_bayes import GaussianNB
X = fn.iloc[:,:-1]
Y = fn.iloc[:,-1]
classifier=GaussianNB()
classifier.fit(X,Y)
# Out:
# GaussianNB()

# %%
pred=classifier.predict(X)
fn["predicted_salary"]=pred
fn
# Out:
#        workclass  education  educationno  maritalstatus  occupation  \
# 0       0.833333   0.600000     0.800000       0.666667    0.000000
# 1       0.666667   0.600000     0.800000       0.333333    0.230769
# 2       0.333333   0.733333     0.533333       0.000000    0.384615
# 3       0.333333   0.066667     0.400000       0.333333    0.384615
# 4       0.333333   0.600000     0.800000       0.333333    0.692308
# ...          ...        ...          ...            ...         ...
# 30156   0.333333   0.466667     0.733333       0.333333    0.923077
# 30157   0.333333   0.733333     0.533333       0.333333    0.461538
# 30158   0.333333   0.733333     0.533333       1.000000    0.000000
# 30159   0.333333   0.733333     0.533333       0.666667    0.000000
# 30160   0.500000   0.733333     0.533333       0.333333    0.230769
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# 0               0.2   1.0  1.0     0.021740          0.0      0.397959
# ...

# %%
pd.crosstab(fn["predicted_salary"],fn["Salary"])
# Out:
# Salary              0.0   1.0
# predicted_salary
# 0.0               21514  5068
# 1.0                1139  2440

# %%
accuracy = sum(fn['predicted_salary']==fn['Salary'])/fn.shape[0]
accuracy
# Out:
# 0.794204436192434

# %%
fn_test=pd.read_csv("SalaryData_Test.csv")
fn_test
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
from sklearn import preprocessing
le=preprocessing.LabelEncoder()
for column_name in fn_test.columns:
    if fn_test[column_name].dtype == object:
        fn_test[column_name] = le.fit_transform(fn_test[column_name])
    else:
        pass
fn_test
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            7              4           6
# 1       38          2         11            9              2           4
# 2       28          1          7           12              2          10
# 3       44          2         15           10              2           6
# 4       34          2          0            6              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           13              4           9
# 15056   39          2          9           13              0           9
# 15057   38          2          9           13              2           9
# 15058   44          2          9           13              0           0
# 15059   35          3          9           13              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
fn_test = norm_func(fn.iloc[:,1:])
fn_test
# Out:
#        education  educationno  maritalstatus  occupation  relationship  race  \
# 0       0.600000     0.800000       0.666667    0.000000           0.2   1.0
# 1       0.600000     0.800000       0.333333    0.230769           0.0   1.0
# 2       0.733333     0.533333       0.000000    0.384615           0.2   1.0
# 3       0.066667     0.400000       0.333333    0.384615           0.0   0.5
# 4       0.600000     0.800000       0.333333    0.692308           1.0   0.5
# ...          ...          ...            ...         ...           ...   ...
# 30156   0.466667     0.733333       0.333333    0.923077           1.0   1.0
# 30157   0.733333     0.533333       0.333333    0.461538           0.0   1.0
# 30158   0.733333     0.533333       1.000000    0.000000           0.8   1.0
# 30159   0.733333     0.533333       0.666667    0.000000           0.6   1.0
# 30160   0.733333     0.533333       0.333333    0.230769           1.0   1.0
#
# ...

# %%
predtest=classifier.predict(X)
fn_test["predicted_salary"]=predtest
fn_test
# Out:
#        education  educationno  maritalstatus  occupation  relationship  race  \
# 0       0.600000     0.800000       0.666667    0.000000           0.2   1.0
# 1       0.600000     0.800000       0.333333    0.230769           0.0   1.0
# 2       0.733333     0.533333       0.000000    0.384615           0.2   1.0
# 3       0.066667     0.400000       0.333333    0.384615           0.0   0.5
# 4       0.600000     0.800000       0.333333    0.692308           1.0   0.5
# ...          ...          ...            ...         ...           ...   ...
# 30156   0.466667     0.733333       0.333333    0.923077           1.0   1.0
# 30157   0.733333     0.533333       0.333333    0.461538           0.0   1.0
# 30158   0.733333     0.533333       1.000000    0.000000           0.8   1.0
# 30159   0.733333     0.533333       0.666667    0.000000           0.6   1.0
# 30160   0.733333     0.533333       0.333333    0.230769           1.0   1.0
#
# ...

# %%
pd.crosstab(fn_test["predicted_salary"],fn_test["Salary"])
# Out:
# Salary              0.0   1.0
# predicted_salary
# 0.0               21514  5068
# 1.0                1139  2440

# %%
accuracy = sum(fn_test['predicted_salary']==fn_test['Salary'])/fn.shape[0]
accuracy
# Out:
# 0.794204436192434
